# %% [markdown]
# Refer here for instructions to [download and run this sample locally](https://developers.arcgis.com/python/sample-notebooks/#Download-and-run-the-sample-notebooks) on your computer

# %% [markdown]
# # Using The GIS
# The GIS object is the most important object when working with the Arcgis Python API. The GIS object represents the GIS you are working with, be it ArcGIS Online or Portal for ArcGIS. You use the GIS object to consume and publish GIS content and administrators may use it to manage GIS users, groups and datastores. The GIS object also includes a number of tools for standard spatial analysis, GeoAnalytics, Raster Analysis and helper services such as geocoding service and geometry service.

# %% [markdown]
# To use the GIS object, import GIS from the `arcgis.gis` module:

# %%
from arcgis.gis import GIS

# %% [markdown]
# To create the GIS object, we pass in the url and our login credentials:

# %%
gis = GIS("https://www.arcgis.com", "gregbrunner_dbs", "gregdemo1")

# %% [markdown]
# Below, we're connecting to ArcGIS Online (the default GIS used when the url is not provided) as an anonymous user:

# %%
gis.users.search("Brunner")
# Out:
# [<User username:gregbrunner_dbs>]

# %% [markdown]
# Adding a '?' mark after an object and querying it brings up help for that object in the notebook:

# %%
gis?

# %% [markdown]
# The notebook provides intellisense and code-completion. Typing a dot after an object and hitting tab brings up a drop-down with it's properties and methods:
# ![dropdown showing members of GIS class](http://esri.github.io/arcgis-python-api/notebooks/nbimages/01-dropdown.png)

# %% [markdown]
# The GIS object provides helper objects to manage the GIS resources, i.e. the users, groups, content and datastores. These helper utilities are in the form of helper objects named: `users`, `groups`, `content` and `datastore` respectively.
#
# Each such helper object has similar patterns of usage: there are methods to `get()`, `search()` and `create()` the respective resources.

# %%
user = gis.users.get('devon')

# %% [markdown]
# The Arcgis Python API is integrated with IPython Notebook to make it easy to visualize and interact with GIS resources. The user object has a rich representation that can be queried like this:

# %%
user
# Out:
# <User username:Devon>

# %% [markdown]
# The resources are implemented as Python dictionaries. You can query for the resource properties using the <b><code>resource['property']</code></b> notation:

# %%
user.fullName

# %% [markdown]
# The properties are also available as properties on the resource object, so you can use the dot notation to access them:

# %%
user.username
# Out:
# 'Devon'

# %% [markdown]
# The resources provide methods to `update()`, `delete()` and use the object.

# %% [markdown]
# The GIS object includes a map widget that can be used to visualize the content of your GIS as well as see the results of your analysis. Let's bring up a map of Palm Springs, CA:

# %%
map1 = gis.map("St. Louis, MO")
map1

# %% [markdown]
# We can search for content in our GIS. Let's search for Hiking Trails in the Palm Springs region. We do that by calling **`gis.content.search()`** and for each web map or web layers that gets returned, we can display it's rich representation within the notebook:

# %%
from IPython.display import display

items = gis.content.search('nigeria')
for item in items:
    display(item)
# Out:
# <Item title:"ICEWS Nigeria 2009-2014" type:Web Map owner:dpiernot_PS>
# <Item title:"ICEWS_Nigeria_2009_2014" type:Feature Service owner:dpiernot_PS>
# <Item title:"ICEWS_BokoHaram" type:Feature Service owner:dpiernot_PS>
# <Item title:"nigeria_gtd1" type:Feature Service owner:wthustonps>
# <Item title:"Nigeria Settlements from Auto FE - Dec Results" type:Web Map owner:Brian_Cross>
# <Item title:"nigeria_since_2012" type:Feature Service owner:wthustonps>
# <Item title:"BokoHaramAttacks" type:Feature Service owner:mich6198PS>
# <Item title:"BokoHaramAttacks" type:Feature Collection owner:mich6198PS>
# <Item title:"Summarize Boko Haram Attacks within Nigeria_Ethnic_Groups" type:Feature Service owner:mich6198PS>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in _repr_html_(self)
#    2641             thumbnail = self.get_thumbnail_link()
#    2642         else:
# -> 2643             b64 = base64.b64encode(self.get_thumbnail())
#    2644             thumbnail = "data:image/png;base64," + str(b64,"utf-8") + "' width='200' height='133"
#    2645
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in get_thumbnail(self)
#    2497             thumbnail_url_path = 'content/items/' + self.itemid + '/info/' + thumbnail_file
#    2498             if thumbnail_url_path:
# -> 2499                 return self._portal.con.get(thumbnail_url_path, try_json=False, force_bytes=True)
#    2500
#    2501     def download_thumbnail(self, save_folder=None):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\_impl\connection.py in get(self, path, params, ssl, compress, try_json, is_retry, use_ordered_dict, out_folder, file_name, force_bytes, add_token, token)
#     757                 raise RuntimeError('Invalid token')
#     758             else:
# --> 759                 raise e
#     760     #----------------------------------------------------------------------
#     761     def _ensure_dir(self, f):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\_impl\connection.py in get(self, path, params, ssl, compress, try_json, is_retry, use_ordered_dict, out_folder, file_name, force_bytes, add_token, token)
#     687             opener.addheaders = headers
#     688
# --> 689             resp = opener.open(url)
#     690
#     691             resp_data, is_file = self._process_response(resp,
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in error(self, proto, *args)
#     508         if http_err:
#     509             args = (dict, 'default', 'http_error_default') + orig_args
# --> 510             return self._call_chain(*args)
#     511
#     512 # XXX probably also want an abstract factory that knows when it makes
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     588 class HTTPDefaultErrorHandler(BaseHandler):
#     589     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 590         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     591
#     592 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request
# <Item title:"BokoHaramAttacks" type:CSV Collection owner:mich6198PS>

# %% [markdown]
# We can then add the returned web layers to our map. To add the last layer returned above, we call map.add_layer() and pass in the layer for Palm Springs Trail:

# %%
map1.add_layer(items[0])

# %% [markdown]
# The above cell updated the map widget, if you scroll to the top, you can notice a new trail layer being rendered on the map.

# %%
items[0]
# Out:
# <Item title:"ICEWS Nigeria 2009-2014" type:Web Map owner:dpiernot_PS>

# %%
from arcgis.features.use_proximity import create_buffers

# %%
from arcgis.features.manage_data import extract_data

# %%
points = gis.content.search("nigeria_gtd", max_items=1, outside_org = True)[0]
points
# Out:
# <Item title:"nigeria_gtd1" type:Feature Service owner:wthustonps>

# %%
map1 = gis.map('Nigeria', 9)

# %%
map1

# %%
map1.add_layer(points)

# %%
query = "iyear = '2015'"
outfields = "*"

# %%
print(type(map1))
# Out:
# <class 'arcgis.widgets.MapView'>

# %%
print(type(points.layers[0]))
# Out:
# <class 'arcgis.features.layer.FeatureLayer'>

# %%
points_lyr = points.layers[0]

# %%
query_layer = points_lyr.query(query, outfields)

# %%
print(query_layer.features)
# Out:
# [{"attributes": {"eventid": 201503000000, "city": "Kirfi district", "iyear": 2015, "latitude": 10.394167, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 29, "longitude": 10.532222, "extended": 0, "country_txt": "Nigeria", "provstate": "Bauchi", "FID": 1093, "resolution": null, "imonth": 3}, "geometry": {"y": 1163472.7383702735, "x": 1172441.5899617134}}, {"attributes": {"eventid": 201503000000, "city": "Alkaleri", "iyear": 2015, "latitude": 10.271304, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 29, "longitude": 10.330143, "extended": 0, "country_txt": "Nigeria", "provstate": "Bauchi", "FID": 1098, "resolution": null, "imonth": 3}, "geometry": {"y": 1149570.228077419, "x": 1149946.2585816993}}, {"attributes": {"eventid": 201503000000, "city": "Alkaleri", "iyear": 2015, "latitude": 10.271304, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 29, "longitude": 10.330143, "extended": 0, "country_txt": "Nigeria", "provstate": "Bauchi", "FID": 1103, "resolution": null, "imonth": 3}, "geometry": {"y": 1149570.228077419, "x": 1149946.2585816993}}, {"attributes": {"eventid": 201503000000, "city": "Port Harcourt", "iyear": 2015, "latitude": 4.815554, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 29, "longitude": 7.049844, "extended": 0, "country_txt": "Nigeria", "provstate": "Rivers", "FID": 1107, "resolution": null, "imonth": 3}, "geometry": {"y": 536697.2582281338, "x": 784785.044252015}}, {"attributes": {"eventid": 201503000000, "city": "Onitsha South district", "iyear": 2015, "latitude": 6.091852, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": "3/29/2015 0:00", "iday": 29, "longitude": 6.757429, "extended": 0, "country_txt": "Nigeria", "provstate": "Anambra", "FID": 1109, "resolution": null, "imonth": 3}, "geometry": {"y": 679423.1672878503, "x": 752233.5553516998}}, {"attributes": {"eventid": 201503000000, "city": "Osogbo", "iyear": 2015, "latitude": 7.766313, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 29, "longitude": 4.566846, "extended": 0, "country_txt": "Nigeria", "provstate": "Osun", "FID": 1112, "resolution": null, "imonth": 3}, "geometry": {"y": 867201.632849435, "x": 508378.97125129827}}, {"attributes": {"eventid": 201503000000, "city": "Tafawa-Balewa", "iyear": 2015, "latitude": 9.756048, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 30, "longitude": 9.556222, "extended": 0, "country_txt": "Nigeria", "provstate": "Bauchi", "FID": 1116, "resolution": null, "imonth": 3}, "geometry": {"y": 1091324.6907967143, "x": 1063793.7669474785}}, {"attributes": {"eventid": 201502000000, "city": "Logo district", "iyear": 2015, "latitude": 7.689167, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 9, "longitude": 9.250278, "extended": 0, "country_txt": "Nigeria", "provstate": "Benue", "FID": 1118, "resolution": null, "imonth": 2}, "geometry": {"y": 858535.070875235, "x": 1029736.2366562211}}, {"attributes": {"eventid": 201503000000, "city": "Jitar", "iyear": 2015, "latitude": 10.223889, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 30, "longitude": 9.8625, "extended": 0, "country_txt": "Nigeria", "provstate": "Bauchi", "FID": 1121, "resolution": null, "imonth": 3}, "geometry": {"y": 1144206.4521731234, "x": 1097888.4779486607}}, {"attributes": {"eventid": 201502000000, "city": "Logo district", "iyear": 2015, "latitude": 7.689167, "region": 11, "region_txt": "Sub-Saharan Africa", "country": 147, "approxdate": null, "iday": 9, "longitude": 9.250278, "extended": 0, "country_txt": "Nigeria", "provstate": "Benue", "FID": 1123, "resolution": null, "imonth": 2}, "geometry": {"y": 858535.070875235, "x": 1029736.2366562211}}, {"attributes":  ...

# %%
csv_lyr = gis.content.get('e66b0295bbeb477bae6221fb938f4ac8')

# %%
csv_lyr = extract_data([csv_lyr])

# %%
csv_lyr.download("C:\\PROJECTS\\R&D\\PYTHON_API")
# Out:
# 'C:\\PROJECTS\\R&D\\PYTHON_API\\extract_data_20170310161407.zip'

# %%
floodprone_buffer = create_buffers(csv_lyr, [ 1 ], units='Miles')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-284ef8e98764> in <module>()
# ----> 1 floodprone_buffer = create_buffers(csv_lyr, [ 1 ], units='Miles')
#
# NameError: name 'create_buffers' is not defined

# %%
map1.add_layer(floodprone_buffer)

# %%
from arcgis.features.analyze_patterns import interpolate_points

# %%
interpolated_points = interpolate_points(items[2], field='Intensity')

# %%
map1.add_layer(interpolated_points['result_layer'])

# %%
from arcgis import features

# %%
items[2].save('C:\PROJECTS\test.shp')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in __getattr__(self, name)
#    2455         try:
# -> 2456             return dict.__getitem__(self, name)
#    2457         except:
#
# KeyError: 'save'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-6ab41b5bae0c> in <module>()
# ----> 1 items[2].save('C:\PROJECTS\test.shp')
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in __getattr__(self, name)
#    2456             return dict.__getitem__(self, name)
#    2457         except:
# -> 2458             raise AttributeError("'%s' object has no attribute '%s'" % (type(self).__name__, name))
#    2459
#    2460     def __getitem__(self, k): # support item attributes as dictionary keys on this object
#
# AttributeError: 'Item' object has no attribute 'save'

# %%
item.download('C:\PROJECTS')
# Out:
# 'C:\\PROJECTS\\BokoHaramAttacks.zip'

# %%
item.name
# Out:
# 'BokoHaramAttacks.zip'

# %%
items[2].save('C:\PROJECTS')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in __getattr__(self, name)
#    2455         try:
# -> 2456             return dict.__getitem__(self, name)
#    2457         except:
#
# KeyError: 'save'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-81cb6242d0d6> in <module>()
# ----> 1 items[2].save('C:\PROJECTS')
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in __getattr__(self, name)
#    2456             return dict.__getitem__(self, name)
#    2457         except:
# -> 2458             raise AttributeError("'%s' object has no attribute '%s'" % (type(self).__name__, name))
#    2459
#    2460     def __getitem__(self, k): # support item attributes as dictionary keys on this object
#
# AttributeError: 'Item' object has no attribute 'save'

# %%
floodprone_buffer.download('C:\PROJECTS')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-d50068123445> in <module>()
# ----> 1 floodprone_buffer.download('C:\PROJECTS')
#
# AttributeError: 'FeatureCollection' object has no attribute 'download'

# %%
items = gis.content.search('nigeria_gtd1')
for item in items:
    display(item)
# Out:
# <Item title:"nigeria_gtd1" type:Feature Service owner:wthustonps>
# <Item title:"nigeria_gtd1" type:Feature Service owner:wthustonps>
# <Item title:"nigeria_gtd1" type:CSV owner:wthustonps>

# %%
item.download("C:\PROJECTS")
# Out:
# 'C:\\PROJECTS\\nigeria_gtd1.csv'

# %%
items[1].download('C:\PROJECTS')
# Out:
# ''

# %%
item.get_data()
# Out:
# 'C:\\Users\\greg6750\\AppData\\Local\\Temp\\nigeria_gtd1.csv'

# %%
item[1].get_data()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in __getitem__(self, k)
#    2461         try:
# -> 2462             return dict.__getitem__(self, k)
#    2463         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-b30724ac1e8c> in <module>()
# ----> 1 item[1].get_data()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis.py in __getitem__(self, k)
#    2462             return dict.__getitem__(self, k)
#    2463         except KeyError:
# -> 2464             if not self._hydrated and not k.startswith('_'):
#    2465                 self._hydrate()
#    2466             return dict.__getitem__(self, k)
#
# AttributeError: 'int' object has no attribute 'startswith'

# %%
it = items[1]

# %%
it.get_data()
# Out:
# ''
