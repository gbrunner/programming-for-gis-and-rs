# %% [markdown]
# # Requests
#
# The [requests](https://requests.readthedocs.io/en/master/) module is an elegant and simple HTTP library for Python. We can use it to get data from websites. Here, let's use it to get some recent COVID-19 data and plot it on a webmap.

# %% [markdown]
# I will demonstrate how to use requests to get COVID-19 data from:
#
# http://nssac.bii.virginia.edu/covid-19/dashboard/data/nssac-ncov-sd-03-15-2020.csv
#
# There is similar data at:
#
# https://github.com/CSSEGISandData/COVID-19/blob/master/archived_data/archived_time_series/time_series_2019-ncov-Recovered.csv

# %% [markdown]
# ## Imports
#
# - We will use ```requests``` to get the data from the CSV via the URL.
# - We will use ```json``` later to format it.
# - We will use ```pandas``` to store the data.
# - We will use ```StringIO``` to format it.

# %%
import requests
import json

# %%
import pandas as pd
from io import StringIO

# %% [markdown]
# Using ```requests``` we can get the data at the URL: http://nssac.bii.virginia.edu/covid-19/dashboard/data/nssac-ncov-sd-03-15-2020.csv

# %%
#headers = {
#    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36',
#    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
#    'Accept-Language': 'en-US,en;q=0.9',
#    'Accept-Encoding': 'gzip, deflate, br',
#    'Connection': 'keep-alive',
#}

url = 'https://nssac.bii.virginia.edu/covid-19/dashboard/data/nssac-ncov-sd-03-15-2020.csv'
r = requests.get(url, verify = False)
# Out:
# C:\Users\greg6750\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone2\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'nssac.bii.virginia.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# We get back a **status code**. If the **status code** is **200** then it worked.

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# ## URL Content
#
# The content of that request can be found in the **content** structure.

# %%
decoded_content = r.content.decode('utf-8')
decoded_content
# Out:
# "name,Region,Last Update,Confirmed,Deaths,Recovered\nHubei,Mainland China,2020-03-16 02:00:00,67798,3099,55094\nGuangdong,Mainland China,2020-03-16 02:00:00,1361,8,1306\nHenan,Mainland China,2020-03-15 02:00:00,1273,22,1250\nZhejiang,Mainland China,2020-03-16 02:00:00,1231,1,1213\nHunan,Mainland China,2020-03-13 02:00:00,1018,4,1004\nAnhui,Mainland China,2020-03-09 01:00:00,990,6,984\nJiangxi,Mainland China,2020-03-13 02:00:00,935,1,934\nShandong,Mainland China,2020-03-16 02:00:00,760,7,743\nJiangsu,Mainland China,2020-03-15 02:00:00,631,0,631\nChongqing,Mainland China,2020-03-16 02:00:00,576,6,570\nSichuan,Mainland China,2020-03-16 02:00:00,539,3,516\nHeilongjiang,Mainland China,2020-03-16 02:00:00,482,13,454\nBeijing,Mainland China,2020-03-16 02:00:00,446,8,358\nShanghai,Mainland China,2020-03-16 02:00:00,355,3,324\nHebei,Mainland China,2020-03-13 02:00:00,318,6,310\nFujian,Mainland China,2020-03-09 01:00:00,296,1,295\nGuangxi,Mainland China,2020-03-16 02:00:00,252,2,247\nShaanxi,Mainland China,2020-03-15 02:00:00,245,2,232\nYunnan,Mainland China,2020-03-15 02:00:00,174,2,172\nHainan,Mainland China,2020-03-13 02:00:00,168,6,160\nGuizhou,Mainland China,2020-03-15 02:00:00,146,2,143\nHong Kong,Hong Kong,2020-03-16 02:00:00,148,4,84\nTianjin,Mainland China,2020-03-13 02:00:00,136,3,132\nShanxi,Mainland China,2020-03-15 02:00:00,133,0,133\nGansu,Mainland China,2020-03-15 02:00:00,132,2,91\nLiaoning,Mainland China,2020-03-16 02:00:00,125,1,114\nJilin,Mainland China,2020-03-16 02:00:00,93,1,92\nXinjiang Uygur,Mainland China,2020-03-09 01:00:00,76,3,73\nNei Mongol,Mainland China,2020-03-11 12:00:00,75,1,71\nNingxia,Mainland China,2020-03-15 02:00:00,75,0,73\nTaiwan,Taiwan,2020-03-16 02:00:00,59,1,20\nQinghai,Mainland China,2020-03-07 01:00:00,18,0,18\nMacau,Macau,2020-03-07 01:00:00,10,0,10\nXizang,Mainland China,2020-02-12 07:00:00,1,0,1\nItaly,Italy,2020-03-15 17:30:00,24747,1809,2335\nIran,Iran,2020-03-15 14:00:00,13938,724,4590\nSouth Korea,South Korea,2020-03-15 14:00:00,8162,75,834\nSpain,Spain,2020-03-16 03:00:00,7844,292,517\nGermany,Germany,2020-03-16 02:00:00 * State Baden-Württemberg 1005; Bavaria 899; Berlin 283; Brandenburg 84; Bremen 56; Hamburg 196; Hesse 286; Mecklenburg-Vorpommern 50; Lower Saxony 287; North Rhine-Westphalia 2113; Rhineland-Palatinate 200; Saarland 74; Saxony 130; Saxony-Anhalt 47; Schleswig-Holstein 103; Thuringia 51; Source: @iceweasel,5864,13,46\nFrance,France,2020-03-16 03:00:00,5437,127,12\nSwitzerland,Switzerland,2020-03-15 20:00:00,2200,14,4\nUnited Kingdom,United Kingdom,2020-03-16 02:00:00,1395,35,21\nNorway,Norway,2020-03-16 03:00:00,1256,3,1\nSweden,Sweden,2020-03-16 03:00:00,1032,3,1\nNetherlands,Netherlands,2020-03-16 02:00:00,1136,20,2\nDenmark,Denmark,2020-03-16 02:00:00,875,2,1\nOthers,Japan (Diamond Princess),2020-03-03 03:00:00,706,6,10\nJapan,Japan,2020-03-16 03:00:00,829,22,157\nBelgium,Belgium,2020-03-15 20:00:00,886,4,1\nAustria,Austria,2020-03-16 03:00:00,860,1,6\nQatar,Qatar,2020-03-16 03:00:00,401,0,4\nAustralia,Australia,2020-03-16 02:00:00,297,3,24\nMalaysia,Malaysia,2020-03-15 20:00:00,428,0,42\nGreece,Greece,2020-03-16 03:00:00,331,4,8\nFinland,Finland,2020-03-16 02:00:00,244,0,10\nSingapore,Singapore,2020-03-15 20:00:00,226,0,105\nBahrain,Bahrain,2020-03-16 03:00:00,214,0,60\nCanada,Canada,2020-03-16 02:00:00 * Ontario 145; British Columbia 73; Alberta 56; Quebec 39; Manitoba 7; New Brunswick 6; Grand pricess 4; Saskatchewan 6; Nova Scotia 3; Prince Edward Island 1; Newfounland and Labrador 1,341,1,9\nIsrael,Esrael,2020-03-16 03:00:00,251,0,4\nCzech Republic,Czech Republic,2020-03-16 03:00:00,253,0,0\nSlovenia,Slovenia,2020-03-15 20:00:00,219,1,0\nPortugal,Portugal,2020-03-15 20:00:00,245,0,2\nIceland,Iceland,2020-03-16 03:00:00,171,5,8\nBrazil,Brazil,2020-03-15 20:00:00,162,0,0\nIreland,Ireland,2020-03-14 21:00:00,129,2,0\nRomania,Romania,2020-03-16 03:00:00,139,0,9\nEstonia,Estonia,2020-03-16 03:00:00,171,0,1\nPhilippines,Philippines,2020-03-16 02:00:00,140,12,2\nIra ...

# %% [markdown]
# ## CSV to Pandas DataFrame
#
# We can push that CSV directly into a pandas dataframe as follows.

# %%
df = pd.read_csv(StringIO(decoded_content), sep=',')

# %%
df.head()
# Out:
#         name          Region          Last Update  Confirmed  Deaths  \
# 0      Hubei  Mainland China  2020-03-16 02:00:00      67798    3099
# 1  Guangdong  Mainland China  2020-03-16 02:00:00       1361       8
# 2      Henan  Mainland China  2020-03-15 02:00:00       1273      22
# 3   Zhejiang  Mainland China  2020-03-16 02:00:00       1231       1
# 4      Hunan  Mainland China  2020-03-13 02:00:00       1018       4
#
#    Recovered
# 0      55094
# 1       1306
# 2       1250
# 3       1213
# 4       1004

# %%
import arcgis
from arcgis.gis import GIS
from arcgis import geocode


gis = GIS("http://slustl.maps.arcgis.com/home", "gregbrunner_slugis")
# Out:
# Enter password: ········

# %%
def get_address(name):
    loc = geocode(name)[0]
    print(name)
    lat = loc['location']['y']
    lon = loc['location']['x']
    return lon, lat

# %%
df['Longitude'], df['Latitude'] = zip(*df.apply(lambda x: get_address(x['name']), axis=1))
# Out:
# Hubei
# Guangdong
# Henan
# Zhejiang
# Hunan
# Anhui
# Jiangxi
# Shandong
# Jiangsu
# Chongqing
# Sichuan
# Heilongjiang
# Beijing
# Shanghai
# Hebei
# Fujian
# Guangxi
# Shaanxi
# Yunnan
# Hainan
# Guizhou
# Hong Kong
# Tianjin
# Shanxi
# Gansu
# Liaoning
# Jilin
# Xinjiang Uygur
# Nei Mongol
# Ningxia
# Taiwan
# Qinghai
# Macau
# Xizang
# Italy
# Iran
# South Korea
# Spain
# Germany
# France
# Switzerland
# United Kingdom
# Norway
# Sweden
# Netherlands
# Denmark
# Others
# Japan
# Belgium
# Austria
# Qatar
# Australia
# Malaysia
# Greece
# Finland
# Singapore
# Bahrain
# Canada
# Israel
# Czech Republic
# Slovenia
# Portugal
# Iceland
# Brazil
# Ireland
# Romania
# Estonia
# Philippines
# Iraq
# Egypt
# Kuwait
# Saudi Arabia
# Poland
# India
# Indonesia
# Lebanon
# United Arab Emirates
# Thailand
# San Marino
# Chile
# Russia
# Vietnam
# Luxembourg
# Serbia
# Slovakia
# Bulgaria
# Brunei
# Albania
# Croatia
# South Africa
# Peru
# Algeria
# Panama
# Argentina
# Pakistan
# Hungary
# Georgia (country)
# Ecuador
# Belarus
# Costa Rica
# Latvia
# Mexico
# Cyprus
# Colombia
# Palestine
# Oman
# Bosnia and Herzegovina
# Armenia
# Malta
# Tunisia
# Morocco
# Azerbaijan
# Moldova
# Bolivia
# Senegal
# Sri Lanka
# Turkey
# Venezuela
# Afghanistan
# North Macedonia
# Maldives
# Lithuania
# Jordan
# Dominican Republic
# Martinique
# French Guiana
# Reunion
# French Polynesia
# Jamaica
# Cambodia
# New Zealand
# Kazakhstan
# Paraguay
# Uruguay
# Cuba
# Liechtenstein
# Guadeloupe
# Bangladesh
# Ukraine
# Ghana
# Aruba
# Cameroon
# Burkina Faso
# Monaco
# Jersey
# Nigeria
# Namibia
# Seychelles
# Democratic Republic of the Congo
# Trinidad and Tobago
# Honduras
# Ethiopia
# Guatemala
# Gabon
# Saint Vincent and the Grenadines
# Kenya
# Saint Lucia
# Mongolia
# Rwanda
# Togo
# Guinea
# Andorra
# Guernsey
# Antigua and Barbuda
# Curacao
# Bhutan
# Sudan
# Nepal
# Suriname
# Cayman Islands
# Cote d'Ivoire
# Mauritania
# Guyana
# Vatican City
# Washington
# New York
# California
# Massachusetts
# Florida
# Colorado
# Georgia
# New Jersey
# Louisiana
# Illinois
# Texas
# Pennsylvania
# Michigan
# Diamond Princess
# Virginia
# Tennessee
# Oregon
# Ohio
# Minnesota
# Maryland
# Wisconsin
# North Carolina
# South Carolina
# Utah
# Connecticut
# Nevada
# Alabama
# Iowa
# Indiana
# Kentucky
# Grand Princess
# Rhode Island
# Nebraska
# New Mexico
# District of Columbia
# Arkansas
# Arizona
# New Hampshire
# Maine
# Mississippi
# South Dakota
# Kansas
# Vermont
# Delaware
# Montana
# Oklahoma
# Hawaii
# Idaho
# Missouri
# Puerto Rico
# Guam
# Wuhan Evacuee
# Wyoming
# North Dakota
# USVI
# Alaska

# %%
df.tail(25)
# Out:
#                      name Region  \
# 205          Rhode Island    USA
# 206              Nebraska    USA
# 207            New Mexico    USA
# 208  District of Columbia    USA
# 209              Arkansas    USA
# 210               Arizona    USA
# 211         New Hampshire    USA
# 212                 Maine    USA
# 213           Mississippi    USA
# 214          South Dakota    USA
# 215                Kansas    USA
# 216               Vermont    USA
# 217              Delaware    USA
# 218               Montana    USA
# 219              Oklahoma    USA
# 220                Hawaii    USA
# 221                 Idaho    USA
# 222              Missouri    USA
# 223           Puerto Rico    USA
# 224                  Guam    USA
# 225         Wuhan Evacuee    USA
# 226               Wyoming    USA
# 227          North Dakota    USA
# 228                  USVI    USA
# 229                Alaska    USA
#
#                                            Last Update  Confirmed  Deaths  \
# 205           2020-03-16 03:00:00 * CTY: Providence 20         20       0
# 206  2020-03-16 03:00:00 * CTY: Douglas 16; Cass 1;...         18       0
# 207  2020-03-16 03:00:00 * CTY: Bernalillo 10; Sant...         17       0
# 208      2020-03-16 03:00:00 * CTY: Washington D.C. 17         17       0
# 209  2020-03-16 03:00:00 * CTY:  9; unknown 4; Jeff...         16       0
# 210  2020-03-16 03:00:00 * CTY: Pinal 5; Maricopa 4...         13       0
# 211  2020-03-16 03:00:00 * CTY: Rockingham 9; Graft...         13       0
# 212  2020-03-16 03:00:00 * CTY:  5; Cumberland 5; L...         12       0
# 213  2020-03-16 03:00:00 * CTY:  4; Forrest 3; Pear...         10       0
# 214  2020-03-16 03:00:00 * CTY: Minnehaha 3; Davids...          9       1
# 215  2020-03-16 03:00:00 * CTY: Johnson 6; Butler 1...          9       1
# 216  2020-03-16 03:00:00 * CTY: Windsor 3; Benningt...          8       0
# 217            2020-03-16 03:00:00 * CTY: New Castle 7          7       0
# 218  2020-03-16 03:00:00 * CTY: Missoula 2; Lewis a...          7       0
# 219  2020-03-16 03:00:00 * CTY: Tulsa 3; Cleveland ...          7       0
# 220  2020-03-16 03:00:00 * CTY: Honolulu 4; Kauai 2...          7       0
# 221  2020-03-16 03:00:00 * CTY: Ada 2; Unknown 1; B...          5       0
# 222  2020-03-16 03:00:00 * CTY: Greene 2; St. Louis...          5       0
# 223           2020-03-16 03:00:00 * CTY: Puerto Rico 5          5       0
# 224                      2020-03-16 03:00:00 * CTY:  3          3       0
# 225                      2020-03-16 03:00:00 * CTY:  3          3       0
# 226  2020-03-16 03:00:00 * CTY: Sheridan County 1; ...          3       0
# 227                  2020-03-16 03:00:00 * CTY: Ward 1          1       0
# 228                      2020-03-16 03:00:00 * CTY:  1          1       0
# 229             2020-03-16 03:00:00 * CTY: Anchorage 1          1       0
#
#      Recovered   Longitude   Latitude
# 205          0  -71.454319  41.488713
# 206          0  -99.811107  41.527270
# 207          0 -106.108404  34.421327
# 208          0  -77.016322  38.904771
# 209          0  -92.438885  34.899924
# 210          1 -111.664754  34.293016
# 211          0  -71.577597  43.685525
# 212          0  -69.203947  45.315250
# 213          0  -89.657176  32.723978
# 214          0 -100.230537  44.436128
# 215          0  -98.380171  38.484727
# 216          0  -72.662689  44.075207
# 217          0  -75.467472  39.008127
# 218          0 -109.645068  47.033499
# 219          0  -97.508599  35.582684
# 220          0 -157.943632  21.439543
# 221          0 -114.659447  44.388995
# 222          0  -92.477747  38.367983
# 223          0  -66.468953  18.222606
# 224          0  144.777628  13.443564
# 225          0  114.324720  30.643530
# 226          0 -107.551610  42.999604
# 227          0 -100.469387  47.446273
# 228          0  -64.819087  17.728114
# 229          0 -151.004158  64.808088

# %% [markdown]
# ## Export to CSV

# %%
df.to_csv(r'C:\Users\greg6750\Documents\IPython Notebooks\intro-prog-for-gis-rs\march_23\covid_19_03_15_2020.csv')

# %% [markdown]
# ## Create a feature collection from it and put it on a wembap

# %%
fc = gis.content.import_data(df)

# %%
fc.properties
# Out:
# {
#   "layerDefinition": {
#     "currentVersion": 10.7,
#     "id": 0,
#     "name": "",
#     "type": "Feature Layer",
#     "displayField": "",
#     "description": "",
#     "copyrightText": "",
#     "defaultVisibility": true,
#     "relationships": [],
#     "isDataVersioned": false,
#     "supportsAppend": true,
#     "supportsCalculate": true,
#     "supportsASyncCalculate": true,
#     "supportsTruncate": false,
#     "supportsAttachmentsByUploadId": true,
#     "supportsAttachmentsResizing": true,
#     "supportsRollbackOnFailureParameter": true,
#     "supportsStatistics": true,
#     "supportsExceedsLimitStatistics": true,
#     "supportsAdvancedQueries": true,
#     "supportsValidateSql": true,
#     "supportsCoordinatesQuantization": true,
#     "supportsFieldDescriptionProperty": true,
#     "supportsQuantizationEditMode": true,
#     "supportsApplyEditsWithGlobalIds": false,
#     "supportsReturningQueryGeometry": true,
#     "advancedQueryCapabilities": {
#       "supportsPagination": true,
#       "supportsPaginationOnAggregatedQueries": true,
#       "supportsQueryRelatedPagination": true,
#       "supportsQueryWithDistance": true,
#       "supportsReturningQueryExtent": true,
#       "supportsStatistics": true,
#       "supportsOrderBy": true,
#       "supportsDistinct": true,
#       "supportsQueryWithResultType": true,
#       "supportsSqlExpression": true,
#       "supportsAdvancedQueryRelated": true,
#       "supportsCountDistinct": true,
#       "supportsPercentileStatistics": true,
#       "supportsReturningGeometryCentroid": false,
#       "supportsQueryWithDatumTransformation": true,
#       "supportsHavingClause": true,
#       "supportsOutFieldSQLExpression": true,
#       "supportsMaxRecordCountFactor": true,
#       "supportsTopFeaturesQuery": true,
#       "supportsDisjointSpatialRel": true,
#       "supportsQueryWithCacheHint": true
#     },
#     "useStandardizedQueries": false,
#     "geometryType": "esriGeometryPoint",
#     "minScale": 0,
#     "maxScale": 0,
#     "extent": {
#       "xmin": -17582204.680487823,
#       "ymin": -5204103.220922415,
#       "xmax": 19185183.147464924,
#       "ymax": 9604936.728098411,
#       "spatialReference": {
#         "wkid": 102100,
#         "latestWkid": 3857
#       }
#     },
#     "drawingInfo": {
#       "renderer": {
#         "type": "simple",
#         "symbol": {
#           "type": "esriPMS",
#           "url": "http://static.arcgis.com/images/Symbols/Basic/RedSphere.png",
#           "imageData": "...",
#           "contentType": "image/png",
#           "width": 15,
#           "height": 15
#         }
#       }
#     },
#     "allowGeometryUpdates": true,
#     "hasAttachments": false,
#     "htmlPopupType": "esriServerHTMLPopupTypeNone",
#     "hasM": false,
#     "hasZ": false,
#     "objectIdField": "ObjectId",
#     "globalIdField": "",
#     "typeIdField": "",
#     "fields": [
#       {
#         "name": "name",
#         "type": "esriFieldTypeString",
#         "alias": "name",
#         "sqlType": "sqlTypeNVarchar",
#         "length": 8000,
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Region",
#         "type": "esriFieldTypeString",
#         "alias": "Region",
#         "sqlType": "sqlTypeNVarchar",
#         "length": 8000,
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Last_Update",
#         "type": "esriFieldTypeDate",
#         "alias": "Last Update",
#         "sqlType": "sqlTypeDate",
#         "length": 256,
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Confirmed",
#         "type": "esriFieldTypeString",
#         "alias": "Confirmed",
#         "sqlType": "sqlTypeNVarchar",
#         "length": 256,
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Deaths",
#         "type": "esriFieldTypeInteger",
#         "alias": "Deaths",
#         "sqlType": "sqlTypeInteger",
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Recovered",
#         "type": "esriFieldTypeInteger",
#         "alias": "Recovered",
#         "sqlType": "sqlTypeInteger",
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Longitude",
#         "type": "esriFieldTypeDouble",
#         "alias": "Longitude",
#         "sqlType": "sqlTypeDouble",
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "Latitude",
#         "type": "esriFieldTypeDouble",
#         "alias": "Latitude",
#         "sqlType": "sqlTypeDouble",
#         "nullable": true,
#         "editable": true,
#         "domain": null,
#         "defaultValue": null
#       },
#       {
#         "name": "ObjectId",
#         "type": "esriFieldTypeOID",
#         "alias": "ObjectId",
#         "sqlType": "sqlTypeInteger",
#         "nullable": false,
#         "editable": false,
#         "domain": null,
#         "defaultValue": null
#       }
#     ],
#     "indexes": [],
#     "types": [],
#     "templates": [
#       {
#         "name": "New Feature",
#         "description": "",
#         "drawingTool": "esriFeatureEditToolPoint",
#         "prototype": {
#           "attributes": {
#             "name": null,
#             "Region": null,
#             "Last_Update": null,
#             "Confirmed": null,
#             "Deaths": null,
#             "Recovered": null,
#             "Longitude": null,
#             "Latitude": null
#           }
#         }
#       }
#     ],
#     "supportedQueryFormats": "JSON, geoJSON",
#     "hasStaticData": false,
#     "maxRecordCount": -1,
#     "standardMaxRecordCount": 32000,
#     "standardMaxRecordCountNoGeometry": 32000,
#     "tileMaxRecordCount": 8000,
#     "maxRecordCountFactor": 1,
#     "capabilities": "Create,Delete,Query,Update,Editing"
#   },
#   "featureSet": {
#     "features": [
#       {
#         "attributes": {
#           "name": "Hubei",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "67798",
#           "Deaths": 3099,
#           "Recovered": 55094,
#           "Longitude": 120.08452,
#           "Latitude": 32.6363700000001,
#           "ObjectId": 1
#         },
#         "geometry": {
#           "x": 13367747.618554689,
#           "y": 3847137.0314964904,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Guangdong",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "1361",
#           "Deaths": 8,
#           "Recovered": 1306,
#           "Longitude": 113,
#           "Latitude": 23.0000000000001,
#           "ObjectId": 2
#         },
#         "geometry": {
#           "x": 12579102.459639927,
#           "y": 2632018.6375864316,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Henan",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "1273",
#           "Deaths": 22,
#           "Recovered": 1250,
#           "Longitude": 114,
#           "Latitude": 34.0000000000001,
#           "ObjectId": 3
#         },
#         "geometry": {
#           "x": 12690421.950433198,
#           "y": 4028802.026134414,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Zhejiang",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "1231",
#           "Deaths": 1,
#           "Recovered": 1213,
#           "Longitude": 120,
#           "Latitude": 29.0000000000001,
#           "ObjectId": 4
#         },
#         "geometry": {
#           "x": 13358338.895192841,
#           "y": 3375646.0349193173,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Hunan",
#           "Region": "Mainland China",
#           "Last_Update": 1584064800000,
#           "Confirmed": "1018",
#           "Deaths": 4,
#           "Recovered": 1004,
#           "Longitude": 112,
#           "Latitude": 28.0000000000001,
#           "ObjectId": 5
#         },
#         "geometry": {
#           "x": 12467782.968846653,
#           "y": 3248973.789650982,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Anhui",
#           "Region": "Mainland China",
#           "Last_Update": 1583715600000,
#           "Confirmed": "990",
#           "Deaths": 6,
#           "Recovered": 984,
#           "Longitude": 117,
#           "Latitude": 32.0000000000001,
#           "ObjectId": 6
#         },
#         "geometry": {
#           "x": 13024380.422813023,
#           "y": 3763310.627144662,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Jiangxi",
#           "Region": "Mainland China",
#           "Last_Update": 1584064800000,
#           "Confirmed": "935",
#           "Deaths": 1,
#           "Recovered": 934,
#           "Longitude": 116,
#           "Latitude": 28.0000000000001,
#           "ObjectId": 7
#         },
#         "geometry": {
#           "x": 12913060.932019746,
#           "y": 3248973.789650982,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Shandong",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "760",
#           "Deaths": 7,
#           "Recovered": 743,
#           "Longitude": 119,
#           "Latitude": 36.0000000000001,
#           "ObjectId": 8
#         },
#         "geometry": {
#           "x": 13247019.404399566,
#           "y": 4300621.372044278,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Jiangsu",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "631",
#           "Deaths": 0,
#           "Recovered": 631,
#           "Longitude": 120,
#           "Latitude": 33.0000000000001,
#           "ObjectId": 9
#         },
#         "geometry": {
#           "x": 13358338.895192841,
#           "y": 3895303.9633939015,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Chongqing",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "576",
#           "Deaths": 6,
#           "Recovered": 570,
#           "Longitude": 106.55278,
#           "Latitude": 29.56278,
#           "ObjectId": 10
#         },
#         "geometry": {
#           "x": 11861401.212207709,
#           "y": 3447472.1861981954,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Sichuan",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "539",
#           "Deaths": 3,
#           "Recovered": 516,
#           "Longitude": 102.5,
#           "Latitude": 30.5000000000001,
#           "ObjectId": 11
#         },
#         "geometry": {
#           "x": 11410247.806310548,
#           "y": 3567983.4559358293,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Heilongjiang",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "482",
#           "Deaths": 13,
#           "Recovered": 454,
#           "Longitude": 128,
#           "Latitude": 48.0000000000001,
#           "ObjectId": 12
#         },
#         "geometry": {
#           "x": 14248894.821539028,
#           "y": 6106854.834885081,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Beijing",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "446",
#           "Deaths": 8,
#           "Recovered": 358,
#           "Longitude": 116.39723,
#           "Latitude": 39.9075,
#           "ObjectId": 13
#         },
#         "geometry": {
#           "x": 12957280.373347549,
#           "y": 4852509.522163179,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Shanghai",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "355",
#           "Deaths": 3,
#           "Recovered": 324,
#           "Longitude": 121.45806,
#           "Latitude": 31.2222200000001,
#           "ObjectId": 14
#         },
#         "geometry": {
#           "x": 13520649.391938873,
#           "y": 3661642.3927813196,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Hebei",
#           "Region": "Mainland China",
#           "Last_Update": 1584064800000,
#           "Confirmed": "318",
#           "Deaths": 6,
#           "Recovered": 310,
#           "Longitude": 116,
#           "Latitude": 39.0000000000001,
#           "ObjectId": 15
#         },
#         "geometry": {
#           "x": 12913060.932019746,
#           "y": 4721671.572580116,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Fujian",
#           "Region": "Mainland China",
#           "Last_Update": 1583715600000,
#           "Confirmed": "296",
#           "Deaths": 1,
#           "Recovered": 295,
#           "Longitude": 117.84278,
#           "Latitude": 26.5450000000001,
#           "ObjectId": 16
#         },
#         "geometry": {
#           "x": 13118198.263263771,
#           "y": 3066739.6155758086,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Guangxi",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "252",
#           "Deaths": 2,
#           "Recovered": 247,
#           "Longitude": 109,
#           "Latitude": 24.0000000000001,
#           "ObjectId": 17
#         },
#         "geometry": {
#           "x": 12133824.496466827,
#           "y": 2753408.1093649855,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Shaanxi",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "245",
#           "Deaths": 2,
#           "Recovered": 232,
#           "Longitude": 109,
#           "Latitude": 36.0000000000001,
#           "ObjectId": 18
#         },
#         "geometry": {
#           "x": 12133824.496466827,
#           "y": 4300621.372044278,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Yunnan",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "174",
#           "Deaths": 2,
#           "Recovered": 172,
#           "Longitude": 102,
#           "Latitude": 25.0000000000001,
#           "ObjectId": 19
#         },
#         "geometry": {
#           "x": 11354588.06091391,
#           "y": 2875744.62435225,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Hainan",
#           "Region": "Mainland China",
#           "Last_Update": 1584064800000,
#           "Confirmed": "168",
#           "Deaths": 6,
#           "Recovered": 160,
#           "Longitude": 109.6,
#           "Latitude": 19.2,
#           "ObjectId": 20
#         },
#         "geometry": {
#           "x": 12200616.190942792,
#           "y": 2178496.8842412466,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Guizhou",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "146",
#           "Deaths": 2,
#           "Recovered": 143,
#           "Longitude": 107,
#           "Latitude": 27.0000000000001,
#           "ObjectId": 21
#         },
#         "geometry": {
#           "x": 11911185.51488028,
#           "y": 3123471.749104584,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Hong Kong",
#           "Region": "Hong Kong",
#           "Last_Update": 1584324000000,
#           "Confirmed": "148",
#           "Deaths": 4,
#           "Recovered": 84,
#           "Longitude": 114.133395414,
#           "Latitude": 22.3646369050001,
#           "ObjectId": 22
#         },
#         "geometry": {
#           "x": 12705271.459993826,
#           "y": 2555360.925416381,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Tianjin",
#           "Region": "Mainland China",
#           "Last_Update": 1584064800000,
#           "Confirmed": "136",
#           "Deaths": 3,
#           "Recovered": 132,
#           "Longitude": 117.17667,
#           "Latitude": 39.1422200000001,
#           "ObjectId": 23
#         },
#         "geometry": {
#           "x": 13044047.23725146,
#           "y": 4742063.889913815,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Shanxi",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "133",
#           "Deaths": 0,
#           "Recovered": 133,
#           "Longitude": 112,
#           "Latitude": 37.0000000000001,
#           "ObjectId": 24
#         },
#         "geometry": {
#           "x": 12467782.968846653,
#           "y": 4439106.787250592,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Gansu",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "132",
#           "Deaths": 2,
#           "Recovered": 91,
#           "Longitude": 102,
#           "Latitude": 38.0000000000001,
#           "ObjectId": 25
#         },
#         "geometry": {
#           "x": 11354588.06091391,
#           "y": 4579425.812870106,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Liaoning",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "125",
#           "Deaths": 1,
#           "Recovered": 114,
#           "Longitude": 123,
#           "Latitude": 41.0000000000001,
#           "ObjectId": 26
#         },
#         "geometry": {
#           "x": 13692297.367572661,
#           "y": 5012341.663847525,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Jilin",
#           "Region": "Mainland China",
#           "Last_Update": 1584324000000,
#           "Confirmed": "93",
#           "Deaths": 1,
#           "Recovered": 92,
#           "Longitude": 126.56028,
#           "Latitude": 43.85083,
#           "ObjectId": 27
#         },
#         "geometry": {
#           "x": 14088625.924254129,
#           "y": 5442386.726876516,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Xinjiang Uygur",
#           "Region": "Mainland China",
#           "Last_Update": 1583715600000,
#           "Confirmed": "76",
#           "Deaths": 3,
#           "Recovered": 73,
#           "Longitude": 6.12774006217902,
#           "Latitude": 49.6009000766057,
#           "ObjectId": 28
#         },
#         "geometry": {
#           "x": 682136.9034353113,
#           "y": 6377443.514104383,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Nei Mongol",
#           "Region": "Mainland China",
#           "Last_Update": 1583928000000,
#           "Confirmed": "75",
#           "Deaths": 1,
#           "Recovered": 71,
#           "Longitude": 112,
#           "Latitude": 44.0000000000001,
#           "ObjectId": 29
#         },
#         "geometry": {
#           "x": 12467782.968846653,
#           "y": 5465442.18332276,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Ningxia",
#           "Region": "Mainland China",
#           "Last_Update": 1584237600000,
#           "Confirmed": "75",
#           "Deaths": 0,
#           "Recovered": 73,
#           "Longitude": 106,
#           "Latitude": 37.0000000000001,
#           "ObjectId": 30
#         },
#         "geometry": {
#           "x": 11799866.024087004,
#           "y": 4439106.787250592,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Taiwan",
#           "Region": "Taiwan",
#           "Last_Update": 1584324000000,
#           "Confirmed": "59",
#           "Deaths": 1,
#           "Recovered": 20,
#           "Longitude": 120.953463961,
#           "Latitude": 23.7528160210001,
#           "ObjectId": 31
#         },
#         "geometry": {
#           "x": 13464478.017821087,
#           "y": 2723316.4628866655,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Qinghai",
#           "Region": "Mainland China",
#           "Last_Update": 1583542800000,
#           "Confirmed": "18",
#           "Deaths": 0,
#           "Recovered": 18,
#           "Longitude": 106.075,
#           "Latitude": 25.8083300000001,
#           "ObjectId": 32
#         },
#         "geometry": {
#           "x": 11808214.985896498,
#           "y": 2975361.094495197,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Macau",
#           "Region": "Macau",
#           "Last_Update": 1583542800000,
#           "Confirmed": "10",
#           "Deaths": 0,
#           "Recovered": 10,
#           "Longitude": 113.56017435,
#           "Latitude": 22.161230275,
#           "ObjectId": 33
#         },
#         "geometry": {
#           "x": 12641460.783037368,
#           "y": 2530893.892239633,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Xizang",
#           "Region": "Mainland China",
#           "Last_Update": 1581490800000,
#           "Confirmed": "1",
#           "Deaths": 0,
#           "Recovered": 1,
#           "Longitude": 90.0000000000001,
#           "Latitude": 32.0000000000001,
#           "ObjectId": 34
#         },
#         "geometry": {
#           "x": 10018754.171394628,
#           "y": 3763310.627144662,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Italy",
#           "Region": "Italy",
#           "Last_Update": 1584293400000,
#           "Confirmed": "24747",
#           "Deaths": 1809,
#           "Recovered": 2335,
#           "Longitude": 12.83333,
#           "Latitude": 42.83333,
#           "ObjectId": 35
#         },
#         "geometry": {
#           "x": 1428599.7607820467,
#           "y": 5286637.283895343,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Iran",
#           "Region": "Iran",
#           "Last_Update": 1584280800000,
#           "Confirmed": "13938",
#           "Deaths": 724,
#           "Recovered": 4590,
#           "Longitude": 54.305910263,
#           "Latitude": 32.5580199520001,
#           "ObjectId": 36
#         },
#         "geometry": {
#           "x": 6045306.277542374,
#           "y": 3836784.380525899,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "South Korea",
#           "Region": "South Korea",
#           "Last_Update": 1584280800000,
#           "Confirmed": "8162",
#           "Deaths": 75,
#           "Recovered": 834,
#           "Longitude": 127.806395933,
#           "Latitude": 36.356270963,
#           "ObjectId": 37
#         },
#         "geometry": {
#           "x": 14227342.91538508,
#           "y": 4349755.093945231,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Spain",
#           "Region": "Spain",
#           "Last_Update": 1584327600000,
#           "Confirmed": "7844",
#           "Deaths": 292,
#           "Recovered": 517,
#           "Longitude": -3.64606310499994,
#           "Latitude": 40.22794966,
#           "ObjectId": 38
#         },
#         "geometry": {
#           "x": -405877.8882487352,
#           "y": 4899122.805186912,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Germany",
#           "Region": "Germany",
#           "Last_Update": null,
#           "Confirmed": "5864",
#           "Deaths": 13,
#           "Recovered": 46,
#           "Longitude": 10.3922779320001,
#           "Latitude": 51.1106310490001,
#           "ObjectId": 39
#         },
#         "geometry": {
#           "x": 1156863.0875724219,
#           "y": 6640886.454659887,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "France",
#           "Region": "France",
#           "Last_Update": 1584327600000,
#           "Confirmed": "5437",
#           "Deaths": 127,
#           "Recovered": 12,
#           "Longitude": 2.55053995300005,
#           "Latitude": 46.559417044,
#           "ObjectId": 40
#         },
#         "geometry": {
#           "x": 283924.808815866,
#           "y": 5870453.905541127,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Switzerland",
#           "Region": "Switzerland",
#           "Last_Update": 1584302400000,
#           "Confirmed": "2200",
#           "Deaths": 14,
#           "Recovered": 4,
#           "Longitude": 8.24502409600007,
#           "Latitude": 46.7998174420001,
#           "ObjectId": 41
#         },
#         "geometry": {
#           "x": 917831.883944998,
#           "y": 5909460.176561419,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "United Kingdom",
#           "Region": "United Kingdom",
#           "Last_Update": 1584324000000,
#           "Confirmed": "1395",
#           "Deaths": 35,
#           "Recovered": 21,
#           "Longitude": -1.96955954399994,
#           "Latitude": 53.408386605,
#           "ObjectId": 42
#         },
#         "geometry": {
#           "x": -219250.3655251049,
#           "y": 7058898.565069394,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Norway",
#           "Region": "Norway",
#           "Last_Update": 1584327600000,
#           "Confirmed": "1256",
#           "Deaths": 3,
#           "Recovered": 1,
#           "Longitude": 10.0000000000001,
#           "Latitude": 62.0000000000001,
#           "ObjectId": 43
#         },
#         "geometry": {
#           "x": 1113194.907932742,
#           "y": 8859142.80056571,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Sweden",
#           "Region": "Sweden",
#           "Last_Update": 1584327600000,
#           "Confirmed": "1032",
#           "Deaths": 3,
#           "Recovered": 1,
#           "Longitude": 17.2604879560001,
#           "Latitude": 64.7125855470001,
#           "ObjectId": 44
#         },
#         "geometry": {
#           "x": 1921428.7301053598,
#           "y": 9533069.287692295,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Netherlands",
#           "Region": "Netherlands",
#           "Last_Update": 1584324000000,
#           "Confirmed": "1136",
#           "Deaths": 20,
#           "Recovered": 2,
#           "Longitude": 5.61612639800006,
#           "Latitude": 52.2493752930001,
#           "ObjectId": 45
#         },
#         "geometry": {
#           "x": 625184.3308560286,
#           "y": 6845341.912820952,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Denmark",
#           "Region": "Denmark",
#           "Last_Update": 1584324000000,
#           "Confirmed": "875",
#           "Deaths": 2,
#           "Recovered": 1,
#           "Longitude": 10.053934054,
#           "Latitude": 55.959300779,
#           "ObjectId": 46
#         },
#         "geometry": {
#           "x": 1119198.8193604352,
#           "y": 7550317.854854343,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Others",
#           "Region": "Japan (Diamond Princess)",
#           "Last_Update": 1583204400000,
#           "Confirmed": "706",
#           "Deaths": 6,
#           "Recovered": 10,
#           "Longitude": -70.2584200555425,
#           "Latitude": 43.6573500000001,
#           "ObjectId": 47
#         },
#         "geometry": {
#           "x": -7821131.544522908,
#           "y": 5412568.5227935435,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Japan",
#           "Region": "Japan",
#           "Last_Update": 1584327600000,
#           "Confirmed": "829",
#           "Deaths": 22,
#           "Recovered": 157,
#           "Longitude": 139.271495,
#           "Latitude": 36.655226998,
#           "ObjectId": 48
#         },
#         "geometry": {
#           "x": 15503631.905417955,
#           "y": 4391158.216300114,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Belgium",
#           "Region": "Belgium",
#           "Last_Update": 1584302400000,
#           "Confirmed": "886",
#           "Deaths": 4,
#           "Recovered": 1,
#           "Longitude": 4.66107042700003,
#           "Latitude": 50.6406829370001,
#           "ObjectId": 49
#         },
#         "geometry": {
#           "x": 518867.9864852292,
#           "y": 6557979.130851168,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Austria",
#           "Region": "Austria",
#           "Last_Update": 1584327600000,
#           "Confirmed": "860",
#           "Deaths": 1,
#           "Recovered": 6,
#           "Longitude": 14.1370769480001,
#           "Latitude": 47.585810005,
#           "ObjectId": 50
#         },
#         "geometry": {
#           "x": 1573732.207156694,
#           "y": 6038222.92305579,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Qatar",
#           "Region": "Qatar",
#           "Last_Update": 1584327600000,
#           "Confirmed": "401",
#           "Deaths": 0,
#           "Recovered": 4,
#           "Longitude": 51.193148324,
#           "Latitude": 25.2854449650001,
#           "ObjectId": 51
#         },
#         "geometry": {
#           "x": 5698795.2035322115,
#           "y": 2910846.0402369755,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Australia",
#           "Region": "Australia",
#           "Last_Update": 1584324000000,
#           "Confirmed": "297",
#           "Deaths": 3,
#           "Recovered": 24,
#           "Longitude": 134.484031198,
#           "Latitude": -25.70993157,
#           "ObjectId": 52
#         },
#         "geometry": {
#           "x": 14970693.87278808,
#           "y": -2963198.8554689414,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Malaysia",
#           "Region": "Malaysia",
#           "Last_Update": 1584302400000,
#           "Confirmed": "428",
#           "Deaths": 0,
#           "Recovered": 42,
#           "Longitude": 112.5,
#           "Latitude": 2.50000000000006,
#           "ObjectId": 53
#         },
#         "geometry": {
#           "x": 12523442.71424329,
#           "y": 278387.07595424104,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Greece",
#           "Region": "Greece",
#           "Last_Update": 1584327600000,
#           "Confirmed": "331",
#           "Deaths": 4,
#           "Recovered": 8,
#           "Longitude": 22.0000000000001,
#           "Latitude": 39.0000000000001,
#           "ObjectId": 54
#         },
#         "geometry": {
#           "x": 2449028.7974520246,
#           "y": 4721671.572580116,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Finland",
#           "Region": "Finland",
#           "Last_Update": 1584324000000,
#           "Confirmed": "244",
#           "Deaths": 0,
#           "Recovered": 10,
#           "Longitude": 26.1588343760001,
#           "Latitude": 64.5225128010001,
#           "ObjectId": 55
#         },
#         "geometry": {
#           "x": 2911988.122481908,
#           "y": 9483708.547943639,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Singapore",
#           "Region": "Singapore",
#           "Last_Update": 1584302400000,
#           "Confirmed": "226",
#           "Deaths": 0,
#           "Recovered": 105,
#           "Longitude": 103.816509136,
#           "Latitude": 1.35344399700006,
#           "ObjectId": 56
#         },
#         "geometry": {
#           "x": 11556800.932954758,
#           "y": 150678.71037104033,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Bahrain",
#           "Region": "Bahrain",
#           "Last_Update": 1584327600000,
#           "Confirmed": "214",
#           "Deaths": 0,
#           "Recovered": 60,
#           "Longitude": 50.5644269540001,
#           "Latitude": 26.051858774,
#           "ObjectId": 57
#         },
#         "geometry": {
#           "x": 5628806.260772963,
#           "y": 3005505.2936581615,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Canada",
#           "Region": "Canada",
#           "Last_Update": null,
#           "Confirmed": "341",
#           "Deaths": 1,
#           "Recovered": 9,
#           "Longitude": -113.64258,
#           "Latitude": 60.1086700000001,
#           "ObjectId": 58
#         },
#         "geometry": {
#           "x": -12650634.13803385,
#           "y": 8423971.909822898,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Israel",
#           "Region": "Esrael",
#           "Last_Update": 1584327600000,
#           "Confirmed": "251",
#           "Deaths": 0,
#           "Recovered": 4,
#           "Longitude": 34.9792176920001,
#           "Latitude": 31.977711512,
#           "ObjectId": 59
#         },
#         "geometry": {
#           "x": 3893868.7018205146,
#           "y": 3760385.272202358,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Czech Republic",
#           "Region": "Czech Republic",
#           "Last_Update": 1584327600000,
#           "Confirmed": "253",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": 15.33177012,
#           "Latitude": 49.73885405,
#           "ObjectId": 60
#         },
#         "geometry": {
#           "x": 1706724.8427179316,
#           "y": 6401172.194157516,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Slovenia",
#           "Region": "Slovenia",
#           "Last_Update": 1584302400000,
#           "Confirmed": "219",
#           "Deaths": 1,
#           "Recovered": 0,
#           "Longitude": 14.821760495,
#           "Latitude": 46.1195548050001,
#           "ObjectId": 61
#         },
#         "geometry": {
#           "x": 1649950.8309632621,
#           "y": 5799528.704120069,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Portugal",
#           "Region": "Portugal",
#           "Last_Update": 1584302400000,
#           "Confirmed": "245",
#           "Deaths": 0,
#           "Recovered": 2,
#           "Longitude": -8.51981298999993,
#           "Latitude": 39.593139046,
#           "ObjectId": 62
#         },
#         "geometry": {
#           "x": -948421.2437007104,
#           "y": 4806993.309603255,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Iceland",
#           "Region": "Iceland",
#           "Last_Update": 1584327600000,
#           "Confirmed": "171",
#           "Deaths": 5,
#           "Recovered": 8,
#           "Longitude": -18.582382346,
#           "Latitude": 64.986956859,
#           "ObjectId": 63
#         },
#         "geometry": {
#           "x": -2068581.3404826333,
#           "y": 9604936.728098411,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Brazil",
#           "Region": "Brazil",
#           "Last_Update": 1584302400000,
#           "Confirmed": "162",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -53.073466889,
#           "Latitude": -10.769946429,
#           "ObjectId": 64
#         },
#         "geometry": {
#           "x": -5908111.308717142,
#           "y": -1206028.136804068,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Ireland",
#           "Region": "Ireland",
#           "Last_Update": 1584219600000,
#           "Confirmed": "129",
#           "Deaths": 2,
#           "Recovered": 0,
#           "Longitude": -8.14600614699998,
#           "Latitude": 53.175879846,
#           "ObjectId": 65
#         },
#         "geometry": {
#           "x": -906809.2562829141,
#           "y": 7015597.426801464,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Romania",
#           "Region": "Romania",
#           "Last_Update": 1584327600000,
#           "Confirmed": "139",
#           "Deaths": 0,
#           "Recovered": 9,
#           "Longitude": 24.9734722150001,
#           "Latitude": 45.8458549750001,
#           "ObjectId": 66
#         },
#         "geometry": {
#           "x": 2780034.210313774,
#           "y": 5755681.687252414,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Estonia",
#           "Region": "Estonia",
#           "Last_Update": 1584327600000,
#           "Confirmed": "171",
#           "Deaths": 0,
#           "Recovered": 1,
#           "Longitude": 25.477224001,
#           "Latitude": 58.6720407870001,
#           "ObjectId": 67
#         },
#         "geometry": {
#           "x": 2836111.6026174906,
#           "y": 8109837.437357576,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Philippines",
#           "Region": "Philippines",
#           "Last_Update": 1584324000000,
#           "Confirmed": "140",
#           "Deaths": 12,
#           "Recovered": 2,
#           "Longitude": 120.86163,
#           "Latitude": 14.1648627970001,
#           "ObjectId": 68
#         },
#         "geometry": {
#           "x": 13454255.108045047,
#           "y": 1593137.6397232984,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Iraq",
#           "Region": "Iraq",
#           "Last_Update": 1584327600000,
#           "Confirmed": "116",
#           "Deaths": 10,
#           "Recovered": 26,
#           "Longitude": 43.7771724180001,
#           "Latitude": 33.0389746700001,
#           "ObjectId": 69
#         },
#         "geometry": {
#           "x": 4873252.541941109,
#           "y": 3900478.3423452587,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Egypt",
#           "Region": "Egypt",
#           "Last_Update": 1584327600000,
#           "Confirmed": "110",
#           "Deaths": 2,
#           "Recovered": 21,
#           "Longitude": 29.8704948600001,
#           "Latitude": 26.5122734930001,
#           "ObjectId": 70
#         },
#         "geometry": {
#           "x": 3325168.2775583025,
#           "y": 3062667.801100517,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Kuwait",
#           "Region": "Kuwait",
#           "Last_Update": 1584327600000,
#           "Confirmed": "112",
#           "Deaths": 0,
#           "Recovered": 9,
#           "Longitude": 47.6121658810001,
#           "Latitude": 29.355337252,
#           "ObjectId": 71
#         },
#         "geometry": {
#           "x": 5300162.0614378005,
#           "y": 3420950.7126150974,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Saudi Arabia",
#           "Region": "Saudi Arabia",
#           "Last_Update": 1584327600000,
#           "Confirmed": "118",
#           "Deaths": 0,
#           "Recovered": 2,
#           "Longitude": 44.5488270600001,
#           "Latitude": 24.121369529,
#           "ObjectId": 72
#         },
#         "geometry": {
#           "x": 4959152.743756814,
#           "y": 2768204.504415956,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Poland",
#           "Region": "Poland",
#           "Last_Update": 1584327600000,
#           "Confirmed": "125",
#           "Deaths": 3,
#           "Recovered": 13,
#           "Longitude": 19.3987689860001,
#           "Latitude": 52.1237901540001,
#           "ObjectId": 73
#         },
#         "geometry": {
#           "x": 2159461.0855378737,
#           "y": 6822539.324992564,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "India",
#           "Region": "India",
#           "Last_Update": null,
#           "Confirmed": "112",
#           "Deaths": 2,
#           "Recovered": 10,
#           "Longitude": 79.4433265480001,
#           "Latitude": 23.379379735,
#           "ObjectId": 74
#         },
#         "geometry": {
#           "x": 8843590.658247119,
#           "y": 2677963.131659853,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Indonesia",
#           "Region": "Indonesia",
#           "Last_Update": 1584327600000,
#           "Confirmed": "117",
#           "Deaths": 5,
#           "Recovered": 8,
#           "Longitude": 113.915865,
#           "Latitude": -0.989818181999965,
#           "ObjectId": 75
#         },
#         "geometry": {
#           "x": 12681056.0850753,
#           "y": -110191.53716954976,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Lebanon",
#           "Region": "Lebanon",
#           "Last_Update": 1584327600000,
#           "Confirmed": "99",
#           "Deaths": 3,
#           "Recovered": 1,
#           "Longitude": 35.8934277440001,
#           "Latitude": 33.9214451660001,
#           "ObjectId": 76
#         },
#         "geometry": {
#           "x": 3995638.0992872454,
#           "y": 4018258.9021683848,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "United Arab Emirates",
#           "Region": "United Arab Emirates",
#           "Last_Update": 1584327600000,
#           "Confirmed": "98",
#           "Deaths": 0,
#           "Recovered": 23,
#           "Longitude": 54.3268581840001,
#           "Latitude": 23.914869621,
#           "ObjectId": 77
#         },
#         "geometry": {
#           "x": 6047638.189441274,
#           "y": 2743038.027932188,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Thailand",
#           "Region": "Thailand",
#           "Last_Update": 1584327600000,
#           "Confirmed": "114",
#           "Deaths": 1,
#           "Recovered": 35,
#           "Longitude": 101.012239206,
#           "Latitude": 15.116802787,
#           "ObjectId": 78
#         },
#         "geometry": {
#           "x": 11244631.032300271,
#           "y": 1702664.9294944254,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
# ...
#           "x": -12986023.778871708,
#           "y": 4772863.966283746,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Alabama",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "22",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -86.8402868589999,
#           "Latitude": 32.766542541,
#           "ObjectId": 201
#         },
#         "geometry": {
#           "x": -9667016.513485681,
#           "y": 3864357.230492901,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Iowa",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "22",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -93.499972411,
#           "Latitude": 42.074698104,
#           "ObjectId": 202
#         },
#         "geometry": {
#           "x": -10408369.317977646,
#           "y": 5172175.433605602,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Indiana",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "21",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -86.2817934879999,
#           "Latitude": 39.919806964,
#           "ObjectId": 203
#         },
#         "geometry": {
#           "x": -9604845.315814542,
#           "y": 4854295.679984807,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Kentucky",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "21",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -85.287620068,
#           "Latitude": 37.5272325240001,
#           "ObjectId": 204
#         },
#         "geometry": {
#           "x": -9494174.436939936,
#           "y": 4512853.225806188,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Grand Princess",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "20",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -74.81265,
#           "Latitude": 11.00291,
#           "ObjectId": 205
#         },
#         "geometry": {
#           "x": -8328106.102895393,
#           "y": 1232436.806324974,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Rhode Island",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "20",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -71.4543194669999,
#           "Latitude": 41.48871294,
#           "ObjectId": 206
#         },
#         "geometry": {
#           "x": -7954258.458046329,
#           "y": 5084696.166541535,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Nebraska",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "18",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -99.811107307,
#           "Latitude": 41.5272703260001,
#           "ObjectId": 207
#         },
#         "geometry": {
#           "x": -11110921.640928026,
#           "y": 5090427.771809097,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "New Mexico",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "17",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -106.108403845,
#           "Latitude": 34.4213265340001,
#           "ObjectId": 208
#         },
#         "geometry": {
#           "x": -11811933.484912425,
#           "y": 4085517.168245908,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "District of Columbia",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "17",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -77.016321746,
#           "Latitude": 38.9047711920001,
#           "ObjectId": 209
#         },
#         "geometry": {
#           "x": -8573417.719535638,
#           "y": 4708040.027993421,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Arkansas",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "16",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -92.4388847,
#           "Latitude": 34.8999237250001,
#           "ObjectId": 210
#         },
#         "geometry": {
#           "x": -10290249.574302122,
#           "y": 4150289.4809059394,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Arizona",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "13",
#           "Deaths": 0,
#           "Recovered": 1,
#           "Longitude": -111.664753988,
#           "Latitude": 34.293016451,
#           "ObjectId": 211
#         },
#         "geometry": {
#           "x": -12430463.55350032,
#           "y": 4068215.165486818,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "New Hampshire",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "13",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -71.577596738,
#           "Latitude": 43.685525247,
#           "ObjectId": 212
#         },
#         "geometry": {
#           "x": -7967981.621080434,
#           "y": 5416904.765733226,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Maine",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "12",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -69.203947061,
#           "Latitude": 45.3152499220001,
#           "ObjectId": 213
#         },
#         "geometry": {
#           "x": -7703748.1477151755,
#           "y": 5671288.424299507,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Mississippi",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "10",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -89.657175808,
#           "Latitude": 32.7239777990001,
#           "ObjectId": 214
#         },
#         "geometry": {
#           "x": -9980591.156909563,
#           "y": 3858723.6826641685,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "South Dakota",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "9",
#           "Deaths": 1,
#           "Recovered": 0,
#           "Longitude": -100.230536743,
#           "Latitude": 44.4361280000001,
#           "ObjectId": 215
#         },
#         "geometry": {
#           "x": -11157612.312167251,
#           "y": 5533183.93181847,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Kansas",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "9",
#           "Deaths": 1,
#           "Recovered": 0,
#           "Longitude": -98.380170629,
#           "Latitude": 38.484726713,
#           "ObjectId": 216
#         },
#         "geometry": {
#           "x": -10951630.498575645,
#           "y": 4648129.56916587,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Vermont",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "8",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -72.662688804,
#           "Latitude": 44.0752070990001,
#           "ObjectId": 217
#         },
#         "geometry": {
#           "x": -8088773.517331377,
#           "y": 5477088.04100021,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Delaware",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "7",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -75.4674721439999,
#           "Latitude": 39.008127276,
#           "ObjectId": 218
#         },
#         "geometry": {
#           "x": -8401000.570525631,
#           "y": 4722835.802002616,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Montana",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "7",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -109.645067732,
#           "Latitude": 47.0334993330001,
#           "ObjectId": 219
#         },
#         "geometry": {
#           "x": -12205633.107920228,
#           "y": 5947543.731401995,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Oklahoma",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "7",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -97.5085993609999,
#           "Latitude": 35.58268395,
#           "ObjectId": 220
#         },
#         "geometry": {
#           "x": -10854607.628831834,
#           "y": 4243350.221891265,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Hawaii",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "7",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -157.94363193,
#           "Latitude": 21.439542579,
#           "ObjectId": 221
#         },
#         "geometry": {
#           "x": -17582204.680487823,
#           "y": 2444367.1814924246,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Idaho",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "5",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -114.659446938,
#           "Latitude": 44.3889953940001,
#           "ObjectId": 222
#         },
#         "geometry": {
#           "x": -12763831.247776527,
#           "y": 5525838.78745526,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Missouri",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "5",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -92.477746617,
#           "Latitude": 38.3679827460001,
#           "ObjectId": 223
#         },
#         "geometry": {
#           "x": -10294575.663113816,
#           "y": 4631540.652964367,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Puerto Rico",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "5",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -66.468953431,
#           "Latitude": 18.2226064980001,
#           "ObjectId": 224
#         },
#         "geometry": {
#           "x": -7399290.049500733,
#           "y": 2063620.7690671808,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Guam",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "3",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": 144.777627805,
#           "Latitude": 13.443563908,
#           "ObjectId": 225
#         },
#         "geometry": {
#           "x": 16116571.805510694,
#           "y": 1510454.2544158062,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Wuhan Evacuee",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "3",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": 114.32472,
#           "Latitude": 30.6435300000001,
#           "ObjectId": 226
#         },
#         "geometry": {
#           "x": 12726569.615483588,
#           "y": 3586540.747092128,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Wyoming",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "3",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -107.551610158,
#           "Latitude": 42.999604339,
#           "ObjectId": 227
#         },
#         "geometry": {
#           "x": -11972590.476785226,
#           "y": 5311911.623500738,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "North Dakota",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "1",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -100.46938737,
#           "Latitude": 47.4462733400001,
#           "ObjectId": 228
#         },
#         "geometry": {
#           "x": -11184201.04234055,
#           "y": 6015223.904649069,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "USVI",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "1",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -64.8190875,
#           "Latitude": 17.728114454,
#           "ObjectId": 229
#         },
#         "geometry": {
#           "x": -7215627.8141846405,
#           "y": 2005749.2094402395,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       },
#       {
#         "attributes": {
#           "name": "Alaska",
#           "Region": "USA",
#           "Last_Update": null,
#           "Confirmed": "1",
#           "Deaths": 0,
#           "Recovered": 0,
#           "Longitude": -151.004157815,
#           "Latitude": 64.8080878980001,
#           "ObjectId": 230
#         },
#         "geometry": {
#           "x": -16809705.955632918,
#           "y": 9558001.620612685,
#           "spatialReference": {
#             "wkid": 102100,
#             "latestWkid": 3857
#           }
#         }
#       }
#     ],
#     "geometryType": "esriGeometryPoint"
#   }
# }

# %%
map1 = gis.map('USA')

# %%
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-dd27f788-b18d-467b-95f8-4e287cd64ead"><img src=""></img></div>

# %%
map1.add_layer(fc,{"renderer":"ClassedSizeRenderer",
                    "field_name": "Deaths"})

# %% [markdown]
# ## Save to Feature Service

# %%
item_properties = {
    "title": "COVID-19 Map",
    "tags" : "coronavirus",
    "snippet": " COVID-19",
    "description": "test description",
    "text": json.dumps({"featureCollection": {"layers": [dict(fc.layer)]}}),
    "type": "Feature Collection",
    "typeKeywords": "Data, Feature Collection, Singlelayer",
    "extent" : "-102.5272,-41.7886,172.5967,64.984"
}

item = gis.content.add(item_properties)
